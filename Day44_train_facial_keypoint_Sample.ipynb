# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0068 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00235, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00235 to 0.00191, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00191 to 0.00190, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00190 to 0.00189, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00189 to 0.00183, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7631e-04 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00183 to 0.00178, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.9553e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00178 to 0.00168, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.0631e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00168 to 0.00155, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 7.3113e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00155 to 0.00153, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 6.4594e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00153 to 0.00136, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.8736e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00136 to 0.00122, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.5191e-04 - val_loss: 0.0012
#
# Epoch 00012: val_loss improved from 0.00122 to 0.00118, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.1054e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00118 to 0.00113, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.8035e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00113 to 0.00107, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.6217e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss improved from 0.00107 to 0.00105, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.4208e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00105 to 0.00103, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.1664e-04 - val_loss: 0.0010
#
# Epoch 00017: val_loss improved from 0.00103 to 0.00100, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.9771e-04 - val_loss: 0.0010
#
# Epoch 00018: val_loss did not improve from 0.00100
# Epoch 19/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.8466e-04 - val_loss: 9.3850e-04
#
# Epoch 00019: val_loss improved from 0.00100 to 0.00094, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.6538e-04 - val_loss: 9.2557e-04
#
# Epoch 00020: val_loss improved from 0.00094 to 0.00093, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.5587e-04 - val_loss: 9.4628e-04
#
# Epoch 00021: val_loss did not improve from 0.00093
# Epoch 22/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.4479e-04 - val_loss: 9.0449e-04
#
# Epoch 00022: val_loss improved from 0.00093 to 0.00090, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.3458e-04 - val_loss: 9.2728e-04
#
# Epoch 00023: val_loss did not improve from 0.00090
# Epoch 24/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.2615e-04 - val_loss: 8.7957e-04
#
# Epoch 00024: val_loss improved from 0.00090 to 0.00088, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.2099e-04 - val_loss: 8.7318e-04
#
# Epoch 00025: val_loss improved from 0.00088 to 0.00087, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1254e-04 - val_loss: 8.3687e-04
#
# Epoch 00026: val_loss improved from 0.00087 to 0.00084, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.9528e-04 - val_loss: 8.3713e-04
#
# Epoch 00027: val_loss did not improve from 0.00084
# Epoch 28/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.9251e-04 - val_loss: 8.3920e-04
#
# Epoch 00028: val_loss did not improve from 0.00084
# Epoch 29/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8079e-04 - val_loss: 8.2288e-04
#
# Epoch 00029: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.7467e-04 - val_loss: 8.5292e-04
#
# Epoch 00030: val_loss did not improve from 0.00082
# Epoch 31/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.7177e-04 - val_loss: 7.8227e-04
#
# Epoch 00031: val_loss improved from 0.00082 to 0.00078, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5488e-04 - val_loss: 7.8530e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5758e-04 - val_loss: 8.2432e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5554e-04 - val_loss: 8.0214e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.4692e-04 - val_loss: 8.2327e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.4520e-04 - val_loss: 7.9703e-04
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.3734e-04 - val_loss: 8.1219e-04
#
# Epoch 00037: val_loss did not improve from 0.00078
# Epoch 38/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.3362e-04 - val_loss: 8.2560e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.3923e-04 - val_loss: 7.9668e-04
#
# Epoch 00039: val_loss did not improve from 0.00078
# Epoch 40/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.2209e-04 - val_loss: 8.1436e-04
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.2052e-04 - val_loss: 8.1161e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.2190e-04 - val_loss: 8.2379e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.1457e-04 - val_loss: 8.2842e-04
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.1239e-04 - val_loss: 7.6337e-04
#
# Epoch 00044: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.0785e-04 - val_loss: 7.9614e-04
#
# Epoch 00045: val_loss did not improve from 0.00076
# Epoch 46/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.0714e-04 - val_loss: 8.2485e-04
#
# Epoch 00046: val_loss did not improve from 0.00076
# Epoch 47/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.0536e-04 - val_loss: 8.2605e-04
#
# Epoch 00047: val_loss did not improve from 0.00076
# Epoch 48/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0493e-04 - val_loss: 7.8155e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0082e-04 - val_loss: 7.5155e-04
#
# Epoch 00049: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9408e-04 - val_loss: 7.6685e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9093e-04 - val_loss: 7.6941e-04
#
# Epoch 00051: val_loss did not improve from 0.00075
# Epoch 52/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9730e-04 - val_loss: 7.9577e-04
#
# Epoch 00052: val_loss did not improve from 0.00075
# Epoch 53/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9345e-04 - val_loss: 7.8760e-04
#
# Epoch 00053: val_loss did not improve from 0.00075
# Epoch 54/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8913e-04 - val_loss: 7.5068e-04
#
# Epoch 00054: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 55/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8214e-04 - val_loss: 7.8568e-04
#
# Epoch 00055: val_loss did not improve from 0.00075
# Epoch 56/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7884e-04 - val_loss: 7.6453e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7676e-04 - val_loss: 8.1150e-04
#
# Epoch 00057: val_loss did not improve from 0.00075
# Epoch 58/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7879e-04 - val_loss: 7.5491e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7233e-04 - val_loss: 8.0177e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7800e-04 - val_loss: 7.8683e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7306e-04 - val_loss: 7.6648e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7153e-04 - val_loss: 7.9617e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7139e-04 - val_loss: 7.7776e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6754e-04 - val_loss: 8.0055e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6505e-04 - val_loss: 8.0496e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6692e-04 - val_loss: 7.8637e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6016e-04 - val_loss: 8.2063e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6355e-04 - val_loss: 7.8738e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5925e-04 - val_loss: 7.7690e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5618e-04 - val_loss: 7.8229e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5314e-04 - val_loss: 7.4948e-04
#
# Epoch 00071: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 72/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5112e-04 - val_loss: 8.1218e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5342e-04 - val_loss: 7.7356e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5370e-04 - val_loss: 7.5915e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4957e-04 - val_loss: 7.7701e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5132e-04 - val_loss: 8.1458e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4975e-04 - val_loss: 7.7467e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4735e-04 - val_loss: 7.8533e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4502e-04 - val_loss: 7.9142e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4548e-04 - val_loss: 7.8630e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
# Epoch 81/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4314e-04 - val_loss: 7.6781e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4244e-04 - val_loss: 7.7751e-04
#
# Epoch 00082: val_loss did not improve from 0.00075
# Epoch 83/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4082e-04 - val_loss: 7.5656e-04
#
# Epoch 00083: val_loss did not improve from 0.00075
# Epoch 84/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.4294e-04 - val_loss: 7.5573e-04
#
# Epoch 00084: val_loss did not improve from 0.00075
# Epoch 85/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4002e-04 - val_loss: 7.7800e-04
#
# Epoch 00085: val_loss did not improve from 0.00075
# Epoch 86/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.4024e-04 - val_loss: 7.7897e-04
#
# Epoch 00086: val_loss did not improve from 0.00075
# Epoch 87/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3449e-04 - val_loss: 7.7126e-04
#
# Epoch 00087: val_loss did not improve from 0.00075
# Epoch 88/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3242e-04 - val_loss: 8.0672e-04
#
# Epoch 00088: val_loss did not improve from 0.00075
# Epoch 89/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3567e-04 - val_loss: 7.6712e-04
#
# Epoch 00089: val_loss did not improve from 0.00075
# Epoch 90/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3276e-04 - val_loss: 7.7749e-04
#
# Epoch 00090: val_loss did not improve from 0.00075
# Epoch 91/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3238e-04 - val_loss: 7.7992e-04
#
# Epoch 00091: val_loss did not improve from 0.00075
# Epoch 92/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3043e-04 - val_loss: 7.7500e-04
#
# Epoch 00092: val_loss did not improve from 0.00075
# Epoch 93/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2781e-04 - val_loss: 8.0656e-04
#
# Epoch 00093: val_loss did not improve from 0.00075
# Epoch 94/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2810e-04 - val_loss: 7.7487e-04
#
# Epoch 00094: val_loss did not improve from 0.00075
# Epoch 95/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2655e-04 - val_loss: 7.8112e-04
#
# Epoch 00095: val_loss did not improve from 0.00075
# Epoch 96/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2328e-04 - val_loss: 8.1144e-04
#
# Epoch 00096: val_loss did not improve from 0.00075
# Epoch 97/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2556e-04 - val_loss: 7.7903e-04
#
# Epoch 00097: val_loss did not improve from 0.00075
# Epoch 98/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2764e-04 - val_loss: 7.8730e-04
#
# Epoch 00098: val_loss did not improve from 0.00075
# Epoch 99/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2642e-04 - val_loss: 7.8654e-04
#
# Epoch 00099: val_loss did not improve from 0.00075
# Epoch 100/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2713e-04 - val_loss: 7.8479e-04
#
# Epoch 00100: val_loss did not improve from 0.00075
# Epoch 101/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2217e-04 - val_loss: 7.8153e-04
#
# Epoch 00101: val_loss did not improve from 0.00075
# Epoch 102/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1994e-04 - val_loss: 7.7759e-04
#
# Epoch 00102: val_loss did not improve from 0.00075
# Epoch 103/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2162e-04 - val_loss: 7.8052e-04
#
# Epoch 00103: val_loss did not improve from 0.00075
# Epoch 104/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2092e-04 - val_loss: 7.8572e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2057e-04 - val_loss: 7.7432e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
# Epoch 106/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2101e-04 - val_loss: 7.7178e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1971e-04 - val_loss: 7.8129e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1724e-04 - val_loss: 7.6355e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1545e-04 - val_loss: 7.8613e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2056e-04 - val_loss: 7.9239e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
# Epoch 111/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1484e-04 - val_loss: 7.8879e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1346e-04 - val_loss: 8.2273e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1414e-04 - val_loss: 8.0999e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1127e-04 - val_loss: 8.1062e-04
#
# Epoch 00114: val_loss did not improve from 0.00075
# Epoch 115/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1299e-04 - val_loss: 7.9517e-04
#
# Epoch 00115: val_loss did not improve from 0.00075
# Epoch 116/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1064e-04 - val_loss: 7.8662e-04
#
# Epoch 00116: val_loss did not improve from 0.00075
# Epoch 117/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1285e-04 - val_loss: 7.9342e-04
#
# Epoch 00117: val_loss did not improve from 0.00075
# Epoch 118/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1376e-04 - val_loss: 7.8426e-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1248e-04 - val_loss: 8.3854e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0739e-04 - val_loss: 7.9159e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
# Epoch 121/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0618e-04 - val_loss: 7.6560e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0469e-04 - val_loss: 7.9385e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0377e-04 - val_loss: 8.0474e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0901e-04 - val_loss: 7.8648e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0736e-04 - val_loss: 7.7877e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
# Epoch 126/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0828e-04 - val_loss: 7.7578e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0381e-04 - val_loss: 7.8858e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0640e-04 - val_loss: 7.6590e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0371e-04 - val_loss: 7.9238e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0530e-04 - val_loss: 7.6162e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
# Epoch 131/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0483e-04 - val_loss: 7.9595e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0087e-04 - val_loss: 8.0216e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0146e-04 - val_loss: 8.2106e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0031e-04 - val_loss: 7.7450e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0066e-04 - val_loss: 8.0618e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
# Epoch 136/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0647e-04 - val_loss: 8.2201e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1156e-04 - val_loss: 7.9991e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0136e-04 - val_loss: 7.9150e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7856e-05 - val_loss: 8.0124e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7800e-05 - val_loss: 8.0506e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.5384e-05 - val_loss: 7.9434e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.7326e-05 - val_loss: 7.9148e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.5745e-05 - val_loss: 7.7153e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.8288e-05 - val_loss: 7.9755e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.5853e-05 - val_loss: 8.0429e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7599e-05 - val_loss: 7.9164e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.9840e-05 - val_loss: 7.8733e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.6727e-05 - val_loss: 8.1283e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.6835e-05 - val_loss: 8.1099e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.3478e-05 - val_loss: 7.6648e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
img_flip_train=np.flip(imgs_train)
points_train_flip=np.flip(points_train)

# %%
checkpoint = ModelCheckpoint('weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(img_flip_train.reshape(-1, 96, 96, 1), 
                       points_train_flip, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=100, verbose=1)
# save the model weights
model.save_weights('weights_flip.h5')
# save the model
model.save('model_flip.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0088 - val_loss: 8.8176e-04
#
# Epoch 00001: val_loss improved from inf to 0.00088, saving model to weights.h5
# Epoch 2/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 9.0529e-04
#
# Epoch 00002: val_loss did not improve from 0.00088
# Epoch 3/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 8.7343e-04
#
# Epoch 00003: val_loss improved from 0.00088 to 0.00087, saving model to weights.h5
# Epoch 4/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 8.6278e-04
#
# Epoch 00004: val_loss improved from 0.00087 to 0.00086, saving model to weights.h5
# Epoch 5/100
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0014 - val_loss: 8.6317e-04
#
# Epoch 00005: val_loss did not improve from 0.00086
# Epoch 6/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 8.1308e-04
#
# Epoch 00006: val_loss improved from 0.00086 to 0.00081, saving model to weights.h5
# Epoch 7/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 8.4869e-04
#
# Epoch 00007: val_loss did not improve from 0.00081
# Epoch 8/100
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0013 - val_loss: 7.5775e-04
#
# Epoch 00008: val_loss improved from 0.00081 to 0.00076, saving model to weights.h5
# Epoch 9/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 7.1520e-04
#
# Epoch 00009: val_loss improved from 0.00076 to 0.00072, saving model to weights.h5
# Epoch 10/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0011 - val_loss: 6.1747e-04
#
# Epoch 00010: val_loss improved from 0.00072 to 0.00062, saving model to weights.h5
# Epoch 11/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0010 - val_loss: 5.5750e-04
#
# Epoch 00011: val_loss improved from 0.00062 to 0.00056, saving model to weights.h5
# Epoch 12/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.9471e-04 - val_loss: 4.8105e-04
#
# Epoch 00012: val_loss improved from 0.00056 to 0.00048, saving model to weights.h5
# Epoch 13/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.1774e-04 - val_loss: 4.6878e-04
#
# Epoch 00013: val_loss improved from 0.00048 to 0.00047, saving model to weights.h5
# Epoch 14/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 7.7308e-04 - val_loss: 4.0746e-04
#
# Epoch 00014: val_loss improved from 0.00047 to 0.00041, saving model to weights.h5
# Epoch 15/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 7.0904e-04 - val_loss: 3.7986e-04
#
# Epoch 00015: val_loss improved from 0.00041 to 0.00038, saving model to weights.h5
# Epoch 16/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 6.8115e-04 - val_loss: 3.8261e-04
#
# Epoch 00016: val_loss did not improve from 0.00038
# Epoch 17/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 6.3007e-04 - val_loss: 3.4500e-04
#
# Epoch 00017: val_loss improved from 0.00038 to 0.00035, saving model to weights.h5
# Epoch 18/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 6.1164e-04 - val_loss: 3.4517e-04
#
# Epoch 00018: val_loss did not improve from 0.00035
# Epoch 19/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.9080e-04 - val_loss: 3.3480e-04
#
# Epoch 00019: val_loss improved from 0.00035 to 0.00033, saving model to weights.h5
# Epoch 20/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.8331e-04 - val_loss: 3.2703e-04
#
# Epoch 00020: val_loss improved from 0.00033 to 0.00033, saving model to weights.h5
# Epoch 21/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.5533e-04 - val_loss: 3.2126e-04
#
# Epoch 00021: val_loss improved from 0.00033 to 0.00032, saving model to weights.h5
# Epoch 22/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.4175e-04 - val_loss: 3.1221e-04
#
# Epoch 00022: val_loss improved from 0.00032 to 0.00031, saving model to weights.h5
# Epoch 23/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.2552e-04 - val_loss: 3.1568e-04
#
# Epoch 00023: val_loss did not improve from 0.00031
# Epoch 24/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.1129e-04 - val_loss: 3.1632e-04
#
# Epoch 00024: val_loss did not improve from 0.00031
# Epoch 25/100
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.9286e-04 - val_loss: 2.9030e-04
#
# Epoch 00025: val_loss improved from 0.00031 to 0.00029, saving model to weights.h5
# Epoch 26/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.8379e-04 - val_loss: 2.7263e-04
#
# Epoch 00026: val_loss improved from 0.00029 to 0.00027, saving model to weights.h5
# Epoch 27/100
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.6379e-04 - val_loss: 2.8373e-04
#
# Epoch 00027: val_loss did not improve from 0.00027
# Epoch 28/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.5038e-04 - val_loss: 2.7296e-04
#
# Epoch 00028: val_loss did not improve from 0.00027
# Epoch 29/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.4403e-04 - val_loss: 2.6272e-04
#
# Epoch 00029: val_loss improved from 0.00027 to 0.00026, saving model to weights.h5
# Epoch 30/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.4103e-04 - val_loss: 2.7305e-04
#
# Epoch 00030: val_loss did not improve from 0.00026
# Epoch 31/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.3900e-04 - val_loss: 2.5306e-04
#
# Epoch 00031: val_loss improved from 0.00026 to 0.00025, saving model to weights.h5
# Epoch 32/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.3197e-04 - val_loss: 2.6976e-04
#
# Epoch 00032: val_loss did not improve from 0.00025
# Epoch 33/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.1469e-04 - val_loss: 2.5319e-04
#
# Epoch 00033: val_loss did not improve from 0.00025
# Epoch 34/100
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.0230e-04 - val_loss: 2.5401e-04
#
# Epoch 00034: val_loss did not improve from 0.00025
# Epoch 35/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.0475e-04 - val_loss: 2.4398e-04
#
# Epoch 00035: val_loss improved from 0.00025 to 0.00024, saving model to weights.h5
# Epoch 36/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.9229e-04 - val_loss: 2.4842e-04
#
# Epoch 00036: val_loss did not improve from 0.00024
# Epoch 37/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.8839e-04 - val_loss: 2.3468e-04
#
# Epoch 00037: val_loss improved from 0.00024 to 0.00023, saving model to weights.h5
# Epoch 38/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.8768e-04 - val_loss: 2.4480e-04
#
# Epoch 00038: val_loss did not improve from 0.00023
# Epoch 39/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.7419e-04 - val_loss: 2.3520e-04
#
# Epoch 00039: val_loss did not improve from 0.00023
# Epoch 40/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.7221e-04 - val_loss: 2.3596e-04
#
# Epoch 00040: val_loss did not improve from 0.00023
# Epoch 41/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.7149e-04 - val_loss: 2.3397e-04
#
# Epoch 00041: val_loss improved from 0.00023 to 0.00023, saving model to weights.h5
# Epoch 42/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.6830e-04 - val_loss: 2.3214e-04
#
# Epoch 00042: val_loss improved from 0.00023 to 0.00023, saving model to weights.h5
# Epoch 43/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.5956e-04 - val_loss: 2.3248e-04
#
# Epoch 00043: val_loss did not improve from 0.00023
# Epoch 44/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.4981e-04 - val_loss: 2.1859e-04
#
# Epoch 00044: val_loss improved from 0.00023 to 0.00022, saving model to weights.h5
# Epoch 45/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.4296e-04 - val_loss: 2.2553e-04
#
# Epoch 00045: val_loss did not improve from 0.00022
# Epoch 46/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.4635e-04 - val_loss: 2.3258e-04
#
# Epoch 00046: val_loss did not improve from 0.00022
# Epoch 47/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.4416e-04 - val_loss: 2.2420e-04
#
# Epoch 00047: val_loss did not improve from 0.00022
# Epoch 48/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.3900e-04 - val_loss: 2.2201e-04
#
# Epoch 00048: val_loss did not improve from 0.00022
# Epoch 49/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.3981e-04 - val_loss: 2.2286e-04
#
# Epoch 00049: val_loss did not improve from 0.00022
# Epoch 50/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.3070e-04 - val_loss: 2.1452e-04
#
# Epoch 00050: val_loss improved from 0.00022 to 0.00021, saving model to weights.h5
# Epoch 51/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.2887e-04 - val_loss: 2.0969e-04
#
# Epoch 00051: val_loss improved from 0.00021 to 0.00021, saving model to weights.h5
# Epoch 52/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.2117e-04 - val_loss: 2.0960e-04
#
# Epoch 00052: val_loss improved from 0.00021 to 0.00021, saving model to weights.h5
# Epoch 53/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1681e-04 - val_loss: 2.1420e-04
#
# Epoch 00053: val_loss did not improve from 0.00021
# Epoch 54/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1478e-04 - val_loss: 2.2518e-04
#
# Epoch 00054: val_loss did not improve from 0.00021
# Epoch 55/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1849e-04 - val_loss: 2.0796e-04
#
# Epoch 00055: val_loss improved from 0.00021 to 0.00021, saving model to weights.h5
# Epoch 56/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1117e-04 - val_loss: 2.0732e-04
#
# Epoch 00056: val_loss improved from 0.00021 to 0.00021, saving model to weights.h5
# Epoch 57/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1150e-04 - val_loss: 2.0477e-04
#
# Epoch 00057: val_loss improved from 0.00021 to 0.00020, saving model to weights.h5
# Epoch 58/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.0616e-04 - val_loss: 2.0939e-04
#
# Epoch 00058: val_loss did not improve from 0.00020
# Epoch 59/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.9856e-04 - val_loss: 2.0430e-04
#
# Epoch 00059: val_loss improved from 0.00020 to 0.00020, saving model to weights.h5
# Epoch 60/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.0001e-04 - val_loss: 2.0503e-04
#
# Epoch 00060: val_loss did not improve from 0.00020
# Epoch 61/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.0034e-04 - val_loss: 2.1116e-04
#
# Epoch 00061: val_loss did not improve from 0.00020
# Epoch 62/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.9036e-04 - val_loss: 2.1218e-04
#
# Epoch 00062: val_loss did not improve from 0.00020
# Epoch 63/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.9354e-04 - val_loss: 1.9938e-04
#
# Epoch 00063: val_loss improved from 0.00020 to 0.00020, saving model to weights.h5
# Epoch 64/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.9174e-04 - val_loss: 2.0146e-04
#
# Epoch 00064: val_loss did not improve from 0.00020
# Epoch 65/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8661e-04 - val_loss: 2.0341e-04
#
# Epoch 00065: val_loss did not improve from 0.00020
# Epoch 66/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8701e-04 - val_loss: 2.0445e-04
#
# Epoch 00066: val_loss did not improve from 0.00020
# Epoch 67/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8022e-04 - val_loss: 2.0683e-04
#
# Epoch 00067: val_loss did not improve from 0.00020
# Epoch 68/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8242e-04 - val_loss: 2.0311e-04
#
# Epoch 00068: val_loss did not improve from 0.00020
# Epoch 69/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.7812e-04 - val_loss: 2.1441e-04
#
# Epoch 00069: val_loss did not improve from 0.00020
# Epoch 70/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.7578e-04 - val_loss: 2.0661e-04
#
# Epoch 00070: val_loss did not improve from 0.00020
# Epoch 71/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.7610e-04 - val_loss: 2.0339e-04
#
# Epoch 00071: val_loss did not improve from 0.00020
# Epoch 72/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.7575e-04 - val_loss: 2.0039e-04
#
# Epoch 00072: val_loss did not improve from 0.00020
# Epoch 73/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.7062e-04 - val_loss: 1.9934e-04
#
# Epoch 00073: val_loss improved from 0.00020 to 0.00020, saving model to weights.h5
# Epoch 74/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.6134e-04 - val_loss: 1.9596e-04
#
# Epoch 00074: val_loss improved from 0.00020 to 0.00020, saving model to weights.h5
# Epoch 75/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.6730e-04 - val_loss: 1.9535e-04
#
# Epoch 00075: val_loss improved from 0.00020 to 0.00020, saving model to weights.h5
# Epoch 76/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.6222e-04 - val_loss: 1.9364e-04
#
# Epoch 00076: val_loss improved from 0.00020 to 0.00019, saving model to weights.h5
# Epoch 77/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5518e-04 - val_loss: 1.9523e-04
#
# Epoch 00077: val_loss did not improve from 0.00019
# Epoch 78/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.6196e-04 - val_loss: 1.9228e-04
#
# Epoch 00078: val_loss improved from 0.00019 to 0.00019, saving model to weights.h5
# Epoch 79/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5741e-04 - val_loss: 1.9260e-04
#
# Epoch 00079: val_loss did not improve from 0.00019
# Epoch 80/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5231e-04 - val_loss: 1.9442e-04
#
# Epoch 00080: val_loss did not improve from 0.00019
# Epoch 81/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5388e-04 - val_loss: 1.9478e-04
#
# Epoch 00081: val_loss did not improve from 0.00019
# Epoch 82/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5418e-04 - val_loss: 1.8869e-04
#
# Epoch 00082: val_loss improved from 0.00019 to 0.00019, saving model to weights.h5
# Epoch 83/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4534e-04 - val_loss: 1.8824e-04
#
# Epoch 00083: val_loss improved from 0.00019 to 0.00019, saving model to weights.h5
# Epoch 84/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4881e-04 - val_loss: 1.9477e-04
#
# Epoch 00084: val_loss did not improve from 0.00019
# Epoch 85/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.4962e-04 - val_loss: 1.9449e-04
#
# Epoch 00085: val_loss did not improve from 0.00019
# Epoch 86/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4623e-04 - val_loss: 2.0101e-04
#
# Epoch 00086: val_loss did not improve from 0.00019
# Epoch 87/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.4641e-04 - val_loss: 1.9179e-04
#
# Epoch 00087: val_loss did not improve from 0.00019
# Epoch 88/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4269e-04 - val_loss: 1.8894e-04
#
# Epoch 00088: val_loss did not improve from 0.00019
# Epoch 89/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3936e-04 - val_loss: 1.8779e-04
#
# Epoch 00089: val_loss improved from 0.00019 to 0.00019, saving model to weights.h5
# Epoch 90/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3883e-04 - val_loss: 1.8894e-04
#
# Epoch 00090: val_loss did not improve from 0.00019
# Epoch 91/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3645e-04 - val_loss: 1.8847e-04
#
# Epoch 00091: val_loss did not improve from 0.00019
# Epoch 92/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3372e-04 - val_loss: 1.8794e-04
#
# Epoch 00092: val_loss did not improve from 0.00019
# Epoch 93/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.3017e-04 - val_loss: 1.9435e-04
#
# Epoch 00093: val_loss did not improve from 0.00019
# Epoch 94/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.3348e-04 - val_loss: 1.9237e-04
#
# Epoch 00094: val_loss did not improve from 0.00019
# Epoch 95/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.3015e-04 - val_loss: 1.8986e-04
#
# Epoch 00095: val_loss did not improve from 0.00019
# Epoch 96/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3425e-04 - val_loss: 1.9713e-04
#
# Epoch 00096: val_loss did not improve from 0.00019
# Epoch 97/100
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.2383e-04 - val_loss: 1.8145e-04
#
# Epoch 00097: val_loss improved from 0.00019 to 0.00018, saving model to weights.h5
# Epoch 98/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2482e-04 - val_loss: 1.8953e-04
#
# Epoch 00098: val_loss did not improve from 0.00018
# Epoch 99/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2816e-04 - val_loss: 1.8421e-04
#
# Epoch 00099: val_loss did not improve from 0.00018
# Epoch 100/100
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3137e-04 - val_loss: 1.8737e-04
#
# Epoch 00100: val_loss did not improve from 0.00018

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
